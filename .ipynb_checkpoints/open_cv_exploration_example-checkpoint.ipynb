# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import cv2

# %%
train_data = pd.read_csv('/domino/datasets/UPRM_Hackathon_2023/train_data_uprm.csv')

# %%
class Config: 
    images_path = '/domino/datasets/UPRM_Hackathon_2023/'

# %% [markdown]
# ### Found below is a sample image from each class

# %%
labels = list(set(train_data['label']))

plt.figure(figsize=(10,10))
for i, label in enumerate(labels):
    df = train_data[train_data['label'] == label].reset_index()
    img = cv2.imread(Config.images_path + '/' +  df['image'][1])
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(img[:,:,::-1])
    plt.title(label)
plt.show()

# %% [markdown]
# ## Using OpenCv as part of preprocessing step

# %% [markdown]
# Using openCv for preprocessing images before feeding them into a CNN can be very useful and, in many cases, can improve the accuracy of the model.
# <br>
#
# Below are several elementary examples. We recommend experimenting with your own!

# %% [markdown]
# ## Adaptive thresholding

# %%
labels = list(set(train_data['label']))

plt.figure(figsize=(10,10))
for i, label in enumerate(labels):
    df = train_data[train_data['label'] == label].reset_index()
    img = cv2.imread(Config.images_path + '/' +  df['image'][0])
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    th3 = cv2.adaptiveThreshold(img,128,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY,11,2)
    plt.imshow(th3,'gray')
    plt.title(label)
plt.show()

# %% [markdown]
# ## CV2 canny edge detection

# %%
labels = list(set(train_data['label']))

plt.figure(figsize=(10,10))
for i, label in enumerate(labels):
    df = train_data[train_data['label'] == label].reset_index()
    img = cv2.imread(Config.images_path + '/' +  df['image'][0])
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    #img = cv2.imread(train_images[i])
    #img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    th3 = cv2.Canny(img,100,500)
    plt.imshow(th3,'gray')
    plt.title(label)
plt.show()

# %%
labels = list(set(train_data['label']))

plt.figure(figsize=(10,10))
for i, label in enumerate(labels):
    df = train_data[train_data['label'] == label].reset_index()
    img = cv2.imread(Config.images_path + '/' +  df['image'][0])
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    ret,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
    thresh1 = thresh1 / 255
    plt.imshow(thresh1)
    plt.title(label)
plt.show()
